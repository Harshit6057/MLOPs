# %%
# !pip install mlflow
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.0
#     Uninstalling numpy-2.4.0:
#       Successfully uninstalled numpy-2.4.0
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Harsh\anaconda3\envs\myperenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Harsh\anaconda3\envs\myperenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Harsh\anaconda3\envs\myperenv\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# embedchain 0.1.128 requires langchain-openai<0.3.0,>=0.2.1, but you have langchain-openai 0.3.29 which is incompatible.
# ...

# %% [markdown]
# # All required commands to install Mlflow on EC2: #

# %%
import mlflow

mlflow.set_tracking_uri("http://ec2-100-31-237-107.compute-1.amazonaws.com:5000/")

with mlflow.start_run():
    mlflow.log_param("param1", 15)
    mlflow.log_metric("metric1", 0.89)

# %%
#creating baseline model

import numpy as np
import pandas as pd
